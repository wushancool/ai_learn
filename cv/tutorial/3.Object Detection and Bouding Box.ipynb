# %%
# !conda install xmltodict -y
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
from voc import VocDataset
from img import img_withbox

base_dir = "/home/wushan/Desktop/data/VOC2012/train/"
dataset = VocDataset(base_dir)
img_name = "2012_004312"

voc_ins = dataset.get_file(img_name)
example = img_withbox(voc_ins.image_file, [voc_ins.bounded_box] + voc_ins.parts)

# %%
img_name = "2007_000027"
voc_ins = dataset.get_file(img_name)
example = img_withbox(voc_ins.image_file, [voc_ins.bounded_box] + voc_ins.parts)
